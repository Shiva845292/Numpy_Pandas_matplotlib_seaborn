# %% [markdown]
# # Reading data from CSV

# %%
import pandas as pd
read=pd.read_csv("https://raw.githubusercontent.com/PramodShenoy/911-Calls/master/911.csv")
read
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %%
read.dtypes
# Out:
# lat          float64
# lng          float64
# desc          object
# zip          float64
# title         object
# timeStamp     object
# twp           object
# addr          object
# e              int64
# dtype: object

# %%
read.describe()
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %%
obj=read.dtypes[read.dtypes=="object"].index
read[obj].describe()
# Out:
#                                                      desc  \
# count                                               99492
# unique                                              99455
# top     GREEN ST & E BASIN ST;  NORRISTOWN; Station 30...
# freq                                                    4
#
#                               title            timeStamp           twp  \
# count                         99492                99492         99449
# unique                          110                72577            68
# top     Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01  LOWER MERION
# freq                          23066                    8          8443
#
#                                      addr
# count                               98973
# unique                              21914
# top     SHANNONDELL DR & SHANNONDELL BLVD
# freq                                  938

# %%
read["lat"]=read["lat"].astype("int")
read
# Out:
#        lat        lng                                               desc  \
# 0       40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1       40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2       40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3       40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4       40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# ...    ...        ...                                                ...
# 99487   40 -75.333515  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...
# 99488   40 -75.289080  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...
# 99489   40 -75.334679  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...
# 99490   40 -75.192555  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...
# 99491   40 -75.317952  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...
#
#            zip                        title            timeStamp  \
# ...

# %%
grp=read.groupby("lat").count()
grp
# Out:
#        lng   desc    zip  title  timeStamp    twp   addr      e
# lat
# 30       1      1      1      1          1      1      1      1
# 32       1      1      1      1          1      1      1      1
# 39    1477   1477   1415   1477       1477   1477   1475   1477
# 40   98012  98012  85219  98012      98012  97970  97495  98012
# 41       1      1      1      1          1      0      1      1

# %%
read[read["lat"]==39]
# Out:
#        lat        lng                                               desc  \
# 73      39 -75.275434  LLOYD LN & DRAYTON LN;  LOWER MERION; Station ...
# 108     39 -75.255749  HEATH RD & ZOLLINGER WAY; LOWER MERION; 2015-1...
# 211     39 -75.259801  HONEYSUCKLE LN & STRAWBERRY LN;  LOWER MERION;...
# 279     39 -75.259985  BEDFORD PL & E WYNNEWOOD RD; LOWER MERION; 201...
# 306     39 -75.256963  CITY AVE & HOLLINGSWORTH RD;  LOWER MERION; St...
# ...    ...        ...                                                ...
# 99073   39 -75.274601  MANOA RD & HAVERFORD RD; LOWER MERION; 2016-08...
# 99163   39 -75.258561  CITY AVE & N 66TH ST; PHILA COUNTY; 2016-08-23...
# 99255   39 -75.256963  CITY AVE & HOLLINGSWORTH RD;  LOWER MERION; St...
# 99273   39 -75.267105  MEREDITH RD & BROADLAWN RD;  LOWER MERION; Sta...
# 99349   39 -75.238908  CITY AVE & LAPSLEY LN;  LOWER MERION; Station ...
#
#            zip                        title            timeStamp  \
# ...

# %%
read["zip"]=read["zip"].fillna(0)
read
# Out:
#        lat        lng                                               desc  \
# 0       40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1       40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2       40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3       40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4       40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# ...    ...        ...                                                ...
# 99487   40 -75.333515  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...
# 99488   40 -75.289080  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...
# 99489   40 -75.334679  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...
# 99490   40 -75.192555  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...
# 99491   40 -75.317952  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...
#
#            zip                        title            timeStamp  \
# ...

# %%
zip=pd.Categorical(read["zip"])
zip
# Out:
# C:\Users\M.shivaprasadreddy\anaconda3\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# [19525.0, 19446.0, 19401.0, 19401.0, 0.0, ..., 19401.0, 19003.0, 19401.0, 19002.0, 19446.0]
# Length: 99492
# Categories (105, float64): [0.0, 17752.0, 18036.0, 18041.0, ..., 19518.0, 19525.0, 36107.0, 77316.0]

# %%
l=[]
count=0
for i in read["zip"]:
    l.append(i)
for i in l:
    if i==0.0:
        pass
    else:
        count+=1
print(count)
print(set(l))
# Out:
# 86637
# {0.0, 19457.0, 19460.0, 77316.0, 19462.0, 18951.0, 19464.0, 19465.0, 19468.0, 18960.0, 19473.0, 19472.0, 19475.0, 18964.0, 19477.0, 18966.0, 18969.0, 18974.0, 18976.0, 19490.0, 19492.0, 19503.0, 19504.0, 19505.0, 19512.0, 19001.0, 19002.0, 19003.0, 19004.0, 19006.0, 19518.0, 19009.0, 19010.0, 19012.0, 19525.0, 19025.0, 19027.0, 19031.0, 19034.0, 19035.0, 19038.0, 19040.0, 19041.0, 19044.0, 19046.0, 19053.0, 18036.0, 18041.0, 19066.0, 19072.0, 19075.0, 18054.0, 18056.0, 19082.0, 19083.0, 19085.0, 19087.0, 19090.0, 18070.0, 19095.0, 19096.0, 18073.0, 18074.0, 18076.0, 19107.0, 19111.0, 19115.0, 18092.0, 19116.0, 19118.0, 19119.0, 19120.0, 19126.0, 18103.0, 19128.0, 19129.0, 19127.0, 19131.0, 19138.0, 19139.0, 19150.0, 19151.0, 36107.0, 17752.0, 19355.0, 19401.0, 19403.0, 19405.0, 19406.0, 19422.0, 19423.0, 19426.0, 18914.0, 19428.0, 18915.0, 19435.0, 19438.0, 18927.0, 19440.0, 19444.0, 18932.0, 19446.0, 18936.0, 19453.0, 19454.0}

# %%
zipl=read.groupby(read["zip"]).count()
zipl
# Out:
#            lat    lng   desc  title  timeStamp    twp   addr      e
# zip
# 0.0      12855  12855  12855  12855      12855  12826  12383  12855
# 17752.0      1      1      1      1          1      0      1      1
# 18036.0      2      2      2      2          2      2      2      2
# 18041.0    414    414    414    414        414    414    414    414
# 18054.0    326    326    326    326        326    326    325    326
# ...        ...    ...    ...    ...        ...    ...    ...    ...
# 19512.0    220    220    220    220        220    220    220    220
# 19518.0     57     57     57     57         57     57     57     57
# 19525.0    965    965    965    965        965    965    961    965
# 36107.0      1      1      1      1          1      1      1      1
# 77316.0      1      1      1      1          1      1      1      1
#
# [105 rows x 8 columns]

# %%
read["zip"].count()
# Out:
# 99492

# %%
l1=[]
for i in read["timeStamp"]:
    l1.append(i[8:10])
read["day"]=l1
read
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %%
A=read[read["addr"].str.startswith('A',na=False)]
A.zip
# Out:
# 3        19401.0
# 43       19406.0
# 48       19468.0
# 72           0.0
# 103      19468.0
#           ...
# 99369    19401.0
# 99371    19401.0
# 99391    19406.0
# 99454    19003.0
# 99465    19401.0
# Name: zip, Length: 2967, dtype: float64

# %%
import datetime
from datetime import date 
Date=[]
date=""
for i in read["timeStamp"]:
    date=i[0:10]
    year, month, day  = date.split('-')     
    day_name = datetime.date(int(year), int(month), int(day)) 
    Date.append(day_name.strftime("%A"))
read["Day"]=Date
read
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %%
import re
services=[]
for i in read["title"]:
    service=list(map(str,re.findall("([A-Za-z]+\:)",i)))
    for i in service:
#         print(i[:-1])
        services.append(i[:-1])
read["service"]=services
read
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %%
read.drop("days", axis=1,inplace=True)
read
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...
