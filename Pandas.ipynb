# %%
import pandas as pd
read=pd.read_csv("titanic.csv")
read
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
read.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
read.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
read.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
read.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
read.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
read.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
read1=pd.read_csv("titanic.csv",names=['Id', 'Survived', 'class', 'Name', 'Sex', 'Age', 'Sib',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],skiprows=(0,1,890))
read1
# Out:
#       Id  Survived  class                                               Name  \
# 0      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1      3         1      3                             Heikkinen, Miss. Laina
# 2      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3      5         0      3                           Allen, Mr. William Henry
# 4      6         0      3                                   Moran, Mr. James
# ..   ...       ...    ...                                                ...
# 884  886         0      3               Rice, Mrs. William (Margaret Norton)
# 885  887         0      2                              Montvila, Rev. Juozas
# 886  888         1      1                       Graham, Miss. Margaret Edith
# 887  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 888  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %%
print(read1["Id"])
print(type(read1["Id"]))
print(read1[["Id","Sex"]])
print(type(read1[["Id","Sex"]]))
# Out:
# 0        2
# 1        3
# 2        4
# 3        5
# 4        6
#       ...
# 884    886
# 885    887
# 886    888
# 887    889
# 888    891
# Name: Id, Length: 889, dtype: int64
# <class 'pandas.core.series.Series'>
#       Id     Sex
# 0      2  female
# 1      3  female
# 2      4  female
# 3      5    male
# 4      6    male
# ..   ...     ...
# 884  886  female
# 885  887    male
# 886  888  female
# 887  889  female
# 888  891    male
#
# [889 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
read1=pd.read_csv("titanic.csv",index_col=["Survived","Pclass"])
read1
# Out:
#                  PassengerId  \
# Survived Pclass
# 0        3                 1
# 1        1                 2
#          3                 3
#          1                 4
# 0        3                 5
# ...                      ...
#          2               887
# 1        1               888
# 0        3               889
# 1        1               890
# 0        3               891
#
#                                                               Name     Sex  \
# Survived Pclass
# 0        3                                 Braund, Mr. Owen Harris    male
# 1        1       Cumings, Mrs. John Bradley (Florence Briggs Th...  female
#          3                                  Heikkinen, Miss. Laina  female
#          1            Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 0        3                                Allen, Mr. William Henry    male
# ...                                                            ...     ...
# ...

# %%
import pandas as pd
read=pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv", 
                 sep=";")
read
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
read.to_csv("shiva.csv",index=False,header=False)#creating new file with csv format in dir location
read
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
l=zip([1,2,3,4],[4,3,21,1])
for i,j in l:
    z={i:j}
    print(z,end="")
# Out:
# {1: 4}{2: 3}{3: 21}{4: 1}

# %%
import pandas as pd
import requests
req= requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
print(req)
print(type(req))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>

# %%
data=req.json()
type(data[0])
# Out:
# dict

# %%
import pandas as pd
import requests
req= requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
data=req.json()
main=pd.DataFrame(columns=["id","node_id","url","name","color","default","description"])
for i in range(len(data)):
    lab=pd.DataFrame(data[i]["labels"])
    main=main.append(lab, ignore_index=True)
main
# Out:
#             id                   node_id  \
# 0        76811      MDU6TGFiZWw3NjgxMQ==
# 1   1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 2      2301354      MDU6TGFiZWwyMzAxMzU0
# 3     42670965  MDU6TGFiZWw0MjY3MDk2NQ==
# 4      2822342      MDU6TGFiZWwyODIyMzQy
# 5     57296398  MDU6TGFiZWw1NzI5NjM5OA==
# 6     87485152  MDU6TGFiZWw4NzQ4NTE1Mg==
# 7        76811      MDU6TGFiZWw3NjgxMQ==
# 8   1639305834  MDU6TGFiZWwxNjM5MzA1ODM0
# 9   1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 10     2301354      MDU6TGFiZWwyMzAxMzU0
# 11    42670965  MDU6TGFiZWw0MjY3MDk2NQ==
# 12      134699      MDU6TGFiZWwxMzQ2OTk=
# 13    35818298  MDU6TGFiZWwzNTgxODI5OA==
# 14   219960758  MDU6TGFiZWwyMTk5NjA3NTg=
# 15   849023693  MDU6TGFiZWw4NDkwMjM2OTM=
# 16     2822098      MDU6TGFiZWwyODIyMDk4
# 17    32815646  MDU6TGFiZWwzMjgxNTY0Ng==
# 18  2085877452  MDU6TGFiZWwyMDg1ODc3NDUy
# 19       76811      MDU6TGFiZWw3NjgxMQ==
# 20    47229171  MDU6TGFiZWw0NzIyOTE3MQ==
# 21   219960758  MDU6TGFiZWwyMTk5NjA3NTg=
# ...

# %%
datas=pd.DataFrame(data, columns=["comments_url","repository_url","events_url","labels_url"])
datas
# Out:
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
l=[datas,main]
need=pd.concat(l,axis=1)
need
# Out:
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
obj="""
  {
     "http://example.org/about": {
         "http://purl.org/dc/terms/title": [
             {"type": "literal", "value": "Anna's Homepage"}
          ]
      }
}
 """
type(obj)
# Out:
# str

# %%
import json
conv=json.loads(obj)
print(type(conv))
print(conv)
# Out:
# <class 'dict'>
# {'http://example.org/about': {'http://purl.org/dc/terms/title': [{'type': 'literal', 'value': "Anna's Homepage"}]}}

# %%
json.dumps(conv)
type(json.dumps(conv))
# Out:
# str

# %%
s=pd.io.json.json_normalize(conv)
s1=pd.DataFrame(s)
for i in (s1):
    print(i)
# Out:
# http://example.org/about.http://purl.org/dc/terms/title
# C:\Users\M461F~1.SHI\AppData\Local\Temp/ipykernel_13416/3474497028.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   s=pd.io.json.json_normalize(conv)

# %%
import pandas as pd
read=pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv", 
                 sep=";")
read.describescribe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
read.dtypes=="int64"
s=read.dtypes[read.dtypes=="int64"].index
x=read.dtypes[read.dtypes=="object"].index
s
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
read[s].describe()
# Out:
#                age      duration      campaign         pdays      previous
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000

# %%
read[x].describe()
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %%
type(read[x].describe())
# Out:
# pandas.core.frame.DataFrame

# %%
read[["education"]][0:10:2]
# Out:
#              education
# 0             basic.4y
# 2          high.school
# 4          high.school
# 6  professional.course
# 8  professional.course

# %%
sorted(read["education"][0:10:2])
# Out:
# ['basic.4y',
#  'high.school',
#  'high.school',
#  'professional.course',
#  'professional.course']

# %%
read.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
import numpy as np
row=np.where(read["age"]==min(read["age"]))
row
# Out:
# (array([37140, 37539, 37558, 37579, 38274], dtype=int64),)

# %%
read.iloc[row]
# Out:
#        age      job marital education default  housing     loan   contact  \
# 37140   17  student  single   unknown      no      yes       no  cellular
# 37539   17  student  single  basic.9y      no      yes       no  cellular
# 37558   17  student  single  basic.9y      no      yes       no  cellular
# 37579   17  student  single  basic.9y      no  unknown  unknown  cellular
# 38274   17  student  single   unknown      no       no      yes  cellular
#
#       month day_of_week  ...  campaign  pdays  previous  poutcome  \
# 37140   aug         wed  ...         3      4         2   success
# 37539   aug         fri  ...         2    999         2   failure
# 37558   aug         fri  ...         3      4         2   success
# 37579   aug         fri  ...         2    999         1   failure
# 38274   oct         tue  ...         1      2         2   success
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# ...

# %%
read.iloc[row][["job",'housing']]
# Out:
#            job  housing
# 37140  student      yes
# 37539  student      yes
# 37558  student      yes
# 37579  student  unknown
# 38274  student       no

# %%
read["Total"]=read["age"]+read["campaign"]
read
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
cat=pd.Categorical(read["housing"])
cat
# Out:
# ['no', 'no', 'yes', 'no', 'no', ..., 'yes', 'no', 'yes', 'no', 'yes']
# Length: 41188
# Categories (3, object): ['no', 'unknown', 'yes']

# %%
excl=pd.read_excel("BUDGET-2022.xlsx",skiprows=[0,15,14,11],names=['Monthly',"Need","Want","Investments","Total"])
excl
# Out:
#       Monthly    Need        Want Investments    Total
# 0     JANUARY  4270.0        1882       15228  21380.0
# 1    FEBRURAY  9426.0       17179        7178  33783.0
# 2       MARCH  8270.0         674        5128  14072.0
# 3      APRIL   1496.0         888        9796  12180.0
# 4         MAY  1168.0        3617        7128  11913.0
# 5        JUNE     NaN         NaN         NaN      NaN
# 6        JULY     NaN         NaN         NaN      NaN
# 7      AUGUST     NaN         NaN         NaN      NaN
# 8   SEPTEMBER     NaN         NaN         NaN      NaN
# 9    NOVEMBER     NaN         NaN         NaN      NaN
# 10   DECEMBER     NaN         NaN         NaN      NaN
# 11        NaN     NaN  Needs only        >50%      NaN
# 12        NaN     NaN  Investment        <20%      NaN

# %%
excl1=pd.read_excel("BUDGET-2022.xlsx",sheet_name="JANUARY",skiprows=[22,21,23,24,25,20,0],usecols=[1,2,3,4],names=["Date","Purpose","Amount","Category","Define"])                                                                                                          
excl1
# Out:
#              Purpose   Amount     Category  \
# 0             Petrol    500.0       Need's
# 1        Travelling     470.0       Want's
# 2               Food    290.0       Want's
# 3   Buying for home     150.0       Need's
# 4            Trading   5000.0  Investments
# 5           Gapchups     20.0       Need's
# 6           Gapchups     20.0       Need's
# 7               Food    188.0       Want's
# 8               Food    934.0       Want's
# 9             Petrol    500.0       Need's
# 10        Investment   5000.0  Investments
# 11        Investment   5000.0  Investments
# 12        Investment    228.0  Investments
# 13          Cutting     100.0       Need's
# 14          medicine    180.0       Need's
# 15            pertol    500.0       Need's
# 16           grocery   2300.0       Need's
# 17               NaN  21380.0          NaN
# 18               NaN      NaN          NaN
#
#                                                Define
# ...

# %%
excl2=pd.read_excel("BUDGET-2022.xlsx",sheet_name="FEBRUARY",skiprows=[22,0],usecols=[1,2,3,4],names=["Date","Purpose","Amount","Category","Define"]) 
excl2
# Out:
#                       Purpose   Amount     Category  \
# 0             Mobile Recharge   1799.0       Need's
# 1                    Gapchups     30.0       Need's
# 2   Marriage Anniversary Gift  15000.0       Want's
# 3                        Food     90.0       Need's
# 4                        Gift    360.0       Want's
# 5                    Donation    500.0       Want's
# 6                    Hospital   1400.0       Need's
# 7                Bike service   1000.0       Need's
# 8                    Gapchups     30.0       Want's
# 9                  Investment   2500.0  Investments
# 10                     Pertol    521.0       Want's
# 11                        PLI   4178.0  Investments
# 12                   Gapchups     20.0       Want's
# 13    Travell for eye surgery    530.0       Need's
# 14           surgery medicine   2500.0       Need's
# 15                 Blood test    800.0       Need's
# 16            checkup Travell    627.0       Need's
# ...

# %%
df=pd.concat([excl1,excl2])
df.reset_index()
# Out:
#     index                    Purpose   Amount     Category  \
# 0       0                     Petrol    500.0       Need's
# 1       1                Travelling     470.0       Want's
# 2       2                       Food    290.0       Want's
# 3       3           Buying for home     150.0       Need's
# 4       4                    Trading   5000.0  Investments
# 5       5                   Gapchups     20.0       Need's
# 6       6                   Gapchups     20.0       Need's
# 7       7                       Food    188.0       Want's
# 8       8                       Food    934.0       Want's
# 9       9                     Petrol    500.0       Need's
# 10     10                 Investment   5000.0  Investments
# 11     11                 Investment   5000.0  Investments
# 12     12                 Investment    228.0  Investments
# 13     13                   Cutting     100.0       Need's
# 14     14                   medicine    180.0       Need's
# ...
