# %%
import pandas as pd
df=pd.read_csv("pokemon_data.csv")
Grass=df[(df["Legendary"]==True) & (df["Type 1"]=="Water")]
Fire=df[(df["Type 1"]=="Fire")]
Fire
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
FG=[Fire,Grass]
dfe=pd.concat(FG,axis=0)
dfe.reset_index()
# Out:
#     index    #                       Name Type 1    Type 2   HP  Attack  \
# 0       4    4                 Charmander   Fire       NaN   39      52
# 1       5    5                 Charmeleon   Fire       NaN   58      64
# 2       6    6                  Charizard   Fire    Flying   78      84
# 3       7    6  CharizardMega Charizard X   Fire    Dragon   78     130
# 4       8    6  CharizardMega Charizard Y   Fire    Flying   78     104
# 5      42   37                     Vulpix   Fire       NaN   38      41
# 6      43   38                  Ninetales   Fire       NaN   73      76
# 7      63   58                  Growlithe   Fire       NaN   55      70
# 8      64   59                   Arcanine   Fire       NaN   90     110
# 9      83   77                     Ponyta   Fire       NaN   50      85
# 10     84   78                   Rapidash   Fire       NaN   65     100
# 11    135  126                     Magmar   Fire       NaN   65      95
# ...

# %%
df.groupby("Type 1").sum().T
# Out:
# Type 1        Bug   Dark  Dragon  Electric  Fairy  Fighting   Fire  Flying  \
# #           23080  14302   15180     15994   7642      9824  17025    2711
# HP           3925   2071    2666      2631   1260      1886   3635     283
# Attack       4897   2740    3588      3040   1046      2613   4408     315
# Defense      4880   2177    2764      2917   1117      1780   3524     265
# Sp. Atk      3717   2314    3099      3961   1335      1434   4627     377
# Sp. Def      4471   2155    2843      3243   1440      1747   3755     290
# Speed        4256   2361    2657      3718    826      1784   3871     410
# Generation    222    125     124       144     70        91    167      22
# Legendary       0      2      12         4      1         0      5       2
#
# Type 1      Ghost  Grass  Ground    Ice  Normal  Poison  Psychic   Rock  \
# #           15568  24141   11401  10165   31279    7050    21706  17280
# HP           2062   4709    2361   1728    7573    1883     4026   2876
# ...

# %%
merg=pd.merge(Grass,Fire,how="left" ,left_on="Type 2",right_on="Type 2")
merg
# Out:
#     #_x               Name_x Type 1_x  Type 2  HP_x  Attack_x  Defense_x  \
# 0   245              Suicune    Water     NaN   100        75        115
# 1   245              Suicune    Water     NaN   100        75        115
# 2   245              Suicune    Water     NaN   100        75        115
# 3   245              Suicune    Water     NaN   100        75        115
# 4   245              Suicune    Water     NaN   100        75        115
# ..  ...                  ...      ...     ...   ...       ...        ...
# 80  382  KyogrePrimal Kyogre    Water     NaN   100       150         90
# 81  382  KyogrePrimal Kyogre    Water     NaN   100       150         90
# 82  382  KyogrePrimal Kyogre    Water     NaN   100       150         90
# 83  382  KyogrePrimal Kyogre    Water     NaN   100       150         90
# 84  484               Palkia    Water  Dragon    90       120        100
#
#     Sp. Atk_x  Sp. Def_x  Speed_x  ...                     Name_y  Type 1_y  \
# ...

# %%
df["HP"]=df["HP"].apply(lambda a : (a*2)+2 )
df
# Out:
#        #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison   92      49       49
# 1      2                Ivysaur    Grass  Poison  122      62       63
# 2      3               Venusaur    Grass  Poison  162      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  162     100      123
# 4      4             Charmander     Fire     NaN   80      52       43
# ..   ...                    ...      ...     ...  ...     ...      ...
# 795  719                Diancie     Rock   Fairy  102     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  102     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  162     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  162     160       60
# 799  721              Volcanion     Fire   Water  162     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.nsmallest(5,"HP")
# Out:
#        #      Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292  Shedinja       Bug  Ghost   1      90       45       30       30
# 55    50   Diglett    Ground    NaN  10      55       25       35       45
# 139  129  Magikarp     Water    NaN  20      10       55       15       20
# 186  172     Pichu  Electric    NaN  20      40       15       35       35
# 230  213   Shuckle       Bug   Rock  20      10      230       10      230
#
#      Speed  Generation Legendary  Total
# 316     40           3         0    236
# 55      95           1         0    265
# 139     80           1         0    200
# 186     60           2         0    205
# 230      5           2         0    505

# %%
obj=df.dtypes[df.dtypes=="object"].index
df[obj].describe()
# Out:
#              Name Type 1  Type 2  Legendary
# count         800    800     414        800
# unique        800     18      18          2
# top     Bulbasaur  Water  Flying          0
# freq            1    112      97        735

# %%
df1=df[(df["Type 1"].notnull()) & (df["Type 2"].notnull())]
df1.count()
# Out:
# #             414
# Name          414
# Type 1        414
# Type 2        414
# HP            414
# Attack        414
# Defense       414
# Sp. Atk       414
# Sp. Def       414
# Speed         414
# Generation    414
# Legendary     414
# dtype: int64

# %%
s=df[df["Type 2"].notnull()]
s.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  414.000000  414.000000  414.000000  414.000000  414.000000  414.000000
# mean   376.565217   70.649758   83.173913   79.676329   77.048309   75.565217
# std    212.840297   22.896557   33.698473   32.593788   33.805061   27.949961
# min      1.000000    1.000000   10.000000   15.000000   10.000000   20.000000
# 25%    205.500000   55.000000   59.250000   55.000000   50.000000   55.000000
# 50%    378.000000   70.000000   80.000000   75.500000   70.000000   75.000000
# 75%    560.750000   85.000000  103.000000  100.000000  100.000000   94.750000
# max    721.000000  150.000000  190.000000  230.000000  180.000000  230.000000
#
#             Speed  Generation       Total
# count  414.000000  414.000000  414.000000
# mean    70.514493    3.410628  456.628019
# std     28.521408    1.663010  120.849502
# min      5.000000    1.000000  190.000000
# 25%     50.000000    2.000000  355.000000
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation      Total
# count  800.000000   800.00000  800.00000
# mean    68.277500     3.32375  435.10250
# std     29.060474     1.66129  119.96304
# min      5.000000     1.00000  180.00000
# 25%     45.000000     2.00000  330.00000
# ...

# %%
df[["HP","Attack"]]
# Out:
#      HP  Attack  Attack
# 0    45      49      49
# 1    60      62      62
# 2    80      82      82
# 3    80     100     100
# 4    39      52      52
# ..   ..     ...     ...
# 795  50     100     100
# 796  50     160     160
# 797  80     110     110
# 798  80     160     160
# 799  80     110     110
#
# [800 rows x 3 columns]

# %%
df[df["Type 2"].isnull()==False]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df1=pd.read_csv("pokemon_data.csv",na_values=0)
df1[df1["Type 2"].isnull()]
# Out:
#        #        Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander    Fire    NaN   39      52       43       60       50
# 5      5  Charmeleon    Fire    NaN   58      64       58       80       65
# 9      7    Squirtle   Water    NaN   44      48       65       50       64
# 10     8   Wartortle   Water    NaN   59      63       80       65       80
# 11     9   Blastoise   Water    NaN   79      83      100       85      105
# ..   ...         ...     ...    ...  ...     ...      ...      ...      ...
# 775  705     Sliggoo  Dragon    NaN   68      75       53       83      113
# 776  706      Goodra  Dragon    NaN   90     100       70      110      150
# 788  712    Bergmite     Ice    NaN   55      69       85       32       35
# 789  713     Avalugg     Ice    NaN   95     117      184       44       46
# 792  716     Xerneas   Fairy    NaN  126     131       95      131       98
#
#      Speed  Generation  Legendary
# ...

# %%
df["Total"]=df["HP"]+df["Attack"]+df["Defense"]+df["Sp. Atk"]+df["Sp. Def"]+df["Speed"]
df2=df[(df["Total"]>600) & (df["Legendary"]==True)]
null=pd.isnull(df2["Type 2"])
df2[1:10:2].fillna("shiva")
df2
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 162  150                 Mewtwo  Psychic       NaN  106     110       90
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 269  249                  Lugia  Psychic    Flying  106      90      130
# 270  250                  Ho-oh     Fire    Flying  106     130       90
# 418  380      LatiasMega Latias   Dragon   Psychic   80     100      120
# 420  381      LatiosMega Latios   Dragon   Psychic   80     130      100
# 421  382                 Kyogre    Water       NaN  100     100       90
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 423  383                Groudon   Ground       NaN  100     150      140
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# 425  384               Rayquaza   Dragon    Flying  105     150       90
# ...

# %%
import numpy as np
df2.loc[df["Legendary"]==False,"Legendary"]=0
df
# Out:
# C:\Users\M.shivaprasadreddy\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# ...

# %%
df[df["Legendary"]==True]
# Out:
#        #                 Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  \
# 156  144             Articuno       Ice   None   90      85      100       95
# 157  145               Zapdos  Electric   None   90      90       85      125
# 158  146              Moltres      Fire   None   90     100       90      125
# 162  150               Mewtwo   Psychic   None  106     110       90      154
# 163  150  MewtwoMega Mewtwo X   Psychic   None  106     190      100      154
# ..   ...                  ...       ...    ...  ...     ...      ...      ...
# 795  719              Diancie      Rock   None   50     100      150      100
# 796  719  DiancieMega Diancie      Rock   None   50     160      110      160
# 797  720  HoopaHoopa Confined   Psychic   None   80     110       60      150
# 798  720   HoopaHoopa Unbound   Psychic   None   80     160       60      170
# 799  721            Volcanion      Fire   None   80     110      120      130
#
# ...

# %%
df["Type 2"].fillna("Empty",inplace=True)

# %%
d=df.dtypes[df.dtypes=="object"].index
df[d].describe()
# Out:
#              Name Type 1 Type 2
# count         800    800    800
# unique        800     18     19
# top     Bulbasaur  Water  Empty
# freq            1    112    386

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df["Type 2"]=df["Type 2"].replace(["NaN"],"Empty")
d=df[1:20]

# %%
d["Type 2"]=d["Type 2"].replace(["NaN"],"Empty")
d.isnull()
# Out:
# C:\Users\M461F~1.SHI\AppData\Local\Temp/ipykernel_1020/864471718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["Type 2"]=d["Type 2"].replace(["NaN"],"Empty")
#         #   Name  Type 1  Type 2     HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1   False  False   False   False  False   False    False    False    False
# 2   False  False   False   False  False   False    False    False    False
# 3   False  False   False   False  False   False    False    False    False
# 4   False  False   False    True  False   False    False    False    False
# 5   False  False   False    True  False   False    False    False    False
# 6   False  False   False   False  False   False    False    False    False
# ...

# %%
df.to_csv("poke.csv",index=False)

# %%
import pandas as pd
poke=pd.read_csv("poke.csv")
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass     NaN  45      49       49
# 1      2                Ivysaur    Grass     NaN  60      62       63
# 2      3               Venusaur    Grass     NaN  80      82       83
# 3      3  VenusaurMega Venusaur    Grass     NaN  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock     NaN  50     100      150
# 796  719    DiancieMega Diancie     Rock     NaN  50     160      110
# 797  720    HoopaHoopa Confined  Psychic     NaN  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic     NaN  80     160       60
# 799  721              Volcanion     Fire     NaN  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
poke.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
nospl=poke[['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk','Sp. Def', 'Speed', 'Generation', 'Legendary']]
nospl
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass     NaN  45      49       49       65
# 1                  Ivysaur    Grass     NaN  60      62       63       80
# 2                 Venusaur    Grass     NaN  80      82       83      100
# 3    VenusaurMega Venusaur    Grass     NaN  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock     NaN  50     100      150      100
# 796    DiancieMega Diancie     Rock     NaN  50     160      110      160
# 797    HoopaHoopa Confined  Psychic     NaN  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic     NaN  80     160       60      170
# 799              Volcanion     Fire     NaN  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
p_=poke[poke["#"].duplicated()][:20]
p_.sort_values("Name")
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 154  142  AerodactylMega Aerodactyl      Rock     NaN   80     135       85
# 71    65      AlakazamMega Alakazam   Psychic     NaN   55      50       65
# 196  181      AmpharosMega Ampharos  Electric     NaN   90      95      105
# 19    15      BeedrillMega Beedrill       Bug     NaN   65     150       40
# 12     9    BlastoiseMega Blastoise     Water     NaN   79     103      120
# 7      6  CharizardMega Charizard X      Fire     NaN   78     130      111
# 8      6  CharizardMega Charizard Y      Fire     NaN   78     104       78
# 102   94          GengarMega Gengar     Ghost     NaN   60      65       80
# 141  130      GyaradosMega Gyarados     Water     NaN   95     155      109
# 232  214    HeracrossMega Heracross       Bug     NaN   80     185      115
# 248  229      HoundoomMega Houndoom      Dark     NaN   75      90       90
# ...

# %%
poke.loc[[23,3]][["Name","Type 1","Speed"]]
# Out:
#                      Name  Type 1  Speed
# 23    PidgeotMega Pidgeot  Normal    121
# 3   VenusaurMega Venusaur   Grass     80

# %%
dic={"a":[1,2,3,4,56,7],"b":[6,5,4,3,2,1],"c":[11,22,3,3,44,6]}
di=pd.DataFrame(dic,index=["A","B","C","D","F","G"])
di
# Out:
#     a  b   c
# A   1  6  11
# B   2  5  22
# C   3  4   3
# D   4  3   3
# F  56  2  44
# G   7  1   6

# %%
di.loc[["A","F"],["a","b"]]
# Out:
#     a  b
# A   1  6
# F  56  2

# %%
di.iloc[[1,2],[1,2]]
# Out:
#    b   c
# B  5  22
# C  4   3

# %%
di.iloc[:2,:-1]
# Out:
#    a  b
# A  1  6
# B  2  5

# %%
di["P"]=di["b"]+di["c"]
di
# Out:
#     a  b   c   P
# A   1  6  11  17
# B   2  5  22  27
# C   3  4   3   7
# D   4  3   3   6
# F  56  2  44  46
# G   7  1   6   7

# %%
di.drop("P",inplace=True, axis=1)
di
# Out:
#     a  b   c
# A   1  6  11
# B   2  5  22
# C   3  4   3
# D   4  3   3
# F  56  2  44
# G   7  1   6

# %%
di
# Out:
#     a  b   c
# A   1  6  11
# B   2  5  22
# C   3  4   3
# D   4  3   3
# F  56  2  44
# G   7  1   6

# %%
di.insert(0, "col1", [100, 100,1,2,3,4], allow_duplicates=True)
di
# Out:
#    col1   a  b   c
# A   100   1  6  11
# B   100   2  5  22
# C     1   3  4   3
# D     2   4  3   3
# F     3  56  2  44
# G     4   7  1   6

# %%
di.loc["A"] = ['Amy', 89, 93,4,] 
di
# Out:
#   col1   a   b   c
# A  Amy  89  93   4
# B  100   2   5  22
# C    1   3   4   3
# D    2   4   3   3
# F    3  56   2  44
# G    4   7   1   6

# %%
di.drop("col1",inplace=True,axis=1)
di
# Out:
#     a   b   c
# A  89  93   4
# B   2   5  22
# C   3   4   3
# D   4   3   3
# F  56   2  44
# G   7   1   6

# %%
di.reset_index()
# Out:
#   index   a   b   c
# 0     A  89  93   4
# 1     B   2   5  22
# 2     C   3   4   3
# 3     D   4   3   3
# 4     F  56   2  44
# 5     G   7   1   6

# %%
di.reset_index(drop=True)
# Out:
#     a   b   c
# 0  89  93   4
# 1   2   5  22
# 2   3   4   3
# 3   4   3   3
# 4  56   2  44
# 5   7   1   6

# %%
di["x"]=["A","B","C","D","R","Q"]
di
# Out:
#     a  b   c  x
# A   1  6  11  A
# B   2  5  22  B
# C   3  4   3  C
# D   4  3   3  D
# F  56  2  44  R
# G   7  1   6  Q

# %%
di.set_index(di["x"])
di
# Out:
#     a  b   c  x
# A   1  6  11  A
# B   2  5  22  B
# C   3  4   3  C
# D   4  3   3  D
# F  56  2  44  R
# G   7  1   6  Q

# %%
import numpy as np
from numpy.random import randn as rn
l=[1,2,3,4,5,6]
l1=[1,1,1,2,2,3]
mult=zip(l1,l)
index_value=pd.MultiIndex.from_tuples(mult)
multi=pd.DataFrame(np.round(rn(6,3)),index=index_value,columns=["A","B","C"])
multi
# Out:
#        A    B    C
# 1 1  0.0 -1.0  0.0
#   2 -1.0  0.0  0.0
#   3  0.0 -2.0  0.0
# 2 4  0.0 -1.0  0.0
#   5 -2.0 -1.0  1.0
# 3 6  1.0 -0.0 -1.0

# %%
multi.loc[1]
# Out:
#      A    B    C
# 1  0.0 -1.0  0.0
# 2 -1.0  0.0  0.0
# 3  0.0 -2.0  0.0

# %%
multi["D"]=["NaN","NaN","NaN",1,2,3]
multi
# Out:
#        A    B    C    D
# 1 1  0.0 -1.0  0.0  NaN
#   2 -1.0  0.0  0.0  NaN
#   3  0.0 -2.0  0.0  NaN
# 2 4  0.0 -1.0  0.0    1
#   5 -2.0 -1.0  1.0    2
# 3 6  1.0 -0.0 -1.0    3

# %%
# Out:
#          A      B      C      D
# 1 1  False  False  False  False
#   2  False  False  False  False
#   3  False  False  False  False
# 2 4  False  False  False  False
#   5  False  False  False  False
# 3 6  False  False  False  False

# %%
# Out:
# Lover,no lover,Lover,no lover,Lover,NO LOVER

# %%
# Out:
# ['2344b', '832u32', '932c']
